# %%
import pandas as pd

# %%
s = pd.Series([10,20,42,56,24,68,55,43],index=["a","b","c","d","e","f","z","v"])
s
# Out:
# <pre>a    10
# b    20
# c    42
# d    56
# e    24
# f    68
# z    55
# v    43
# dtype: int64</pre>

# %%
df = pd.DataFrame({
    "imię":["Anna","Bartek","Celina"],
    "wiek":[67,32,31],
    "miasto":["Warszawa","Kraków","Lublin"]
},index=["a","b","c"])

df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>imię</th>
#       <th>wiek</th>
#       <th>miasto</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>a</th>
#       <td>Anna</td>
#       <td>67</td>
#       <td>Warszawa</td>
#     </tr>
#     <tr>
#       <th>b</th>
#       <td>Bartek</td>
#       <td>32</td>
#       <td>Kraków</td>
#     </tr>
#     <tr>
#       <th>c</th>
#       <td>Celina</td>
#       <td>31</td>
#       <td>Lublin</td>
#     </tr>
#   </tbody>
# </table>
# </div>
